# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as stats

# %%
play_df = pd.read_csv("datasets/spotify_playlists_output.csv")
play_df
# Out:
#       Unnamed: 0                Track ID                  Track Name  \
# 0              0  0sf12qNH5qcw8qpgymFOqD             Blinding Lights
# 1              1  2usxQITOSDqvkYiI0oIwao           You should be sad
# 2              2  0nbXyq5TXYPCO7pr3N8S4I                     The Box
# 3              3  2Fxmhks0bxGSBdJ92vM42m                     bad guy
# 4              4  4TnjEaWOeW0eKTKIEvJyCa                     Falling
# ...          ...                     ...                         ...
# 1536        1536  2zUbimuKNWDMCwbqNauLWV  B*tch From Da Souf (Remix)
# 1537        1537  3uIVdQmgp3IPLC8vXgZmgv                  God's Hand
# 1538        1538  5bVaWFbTBV7tSs6L0ZnILR                       Betta
# 1539        1539  5LwJdYY3SorVljsVx6J6Uw                    Still Me
# 1540        1540  2v0W9sS9vWn5NLZ8MBtnlr             Suburban, Pt. 2
#
#             Track Added At  Track Popularity  Track Duration  \
# 0     2020-01-28T11:01:50Z                98          201573
# ...

# %%
play_df.plot(kind="scatter", x='Available Markets', y='Track Popularity', grid=True,
              title='Popularity vs. Available Markets', edgecolors='black', color='green')

# %%
play_df.plot(kind="scatter", x='Track Duration', y='Track Popularity', grid=True,
              title='Popularity vs. Duration', edgecolors='black', color='green')

# %%
play2_df = pd.read_csv("datasets/playlist_top_5_output.csv")
play2_df
# Out:
#       Unnamed: 0                Track ID         Track Name  \
# 0              0  2usxQITOSDqvkYiI0oIwao  You should be sad
# 1              1  0nbXyq5TXYPCO7pr3N8S4I            The Box
# 2              2  2Fxmhks0bxGSBdJ92vM42m            bad guy
# 3              3  0sf12qNH5qcw8qpgymFOqD    Blinding Lights
# 4              4  4TnjEaWOeW0eKTKIEvJyCa            Falling
# ...          ...                     ...                ...
# 4401        4401  1wYJnu1hMrYMNrkXKTVrYd     Gives You Hell
# 4402        4402  3wZZzzTEdLRYLVTp0UnaFH            Secrets
# 4403        4403  1yjY7rpaAQvKwpdUliHx0d     Still into You
# 4404        4404  1hIupFeRu3nmMcjbjxPnMc     I'm Just A Kid
# 4405        4405  1i2t3VyIcsAonPhK6wjuJp   Drown In My Mind
#
#             Track Added At  Track Popularity  Track Duration  \
# 0     2020-01-29T19:04:50Z                89          205473
# 1     2020-01-29T19:04:50Z               100          196652
# ...

# %%
play2_df.plot(kind="scatter", x='Available Markets', y='Track Popularity', grid=True,
              title='Popularity vs. Available Markets', edgecolors='black', color='green')

# %%
play2_df.plot(kind="scatter", x='Track Duration', y='Track Popularity', grid=True,
              title='Popularity vs. Duration', edgecolors='black', color='green')

# %%
play2_df
# Out:
#       Unnamed: 0                Track ID         Track Name  \
# 0              0  2usxQITOSDqvkYiI0oIwao  You should be sad
# 1              1  0nbXyq5TXYPCO7pr3N8S4I            The Box
# 2              2  2Fxmhks0bxGSBdJ92vM42m            bad guy
# 3              3  0sf12qNH5qcw8qpgymFOqD    Blinding Lights
# 4              4  4TnjEaWOeW0eKTKIEvJyCa            Falling
# ...          ...                     ...                ...
# 4401        4401  1wYJnu1hMrYMNrkXKTVrYd     Gives You Hell
# 4402        4402  3wZZzzTEdLRYLVTp0UnaFH            Secrets
# 4403        4403  1yjY7rpaAQvKwpdUliHx0d     Still into You
# 4404        4404  1hIupFeRu3nmMcjbjxPnMc     I'm Just A Kid
# 4405        4405  1i2t3VyIcsAonPhK6wjuJp   Drown In My Mind
#
#             Track Added At  Track Popularity  Track Duration  \
# 0     2020-01-29T19:04:50Z                89          205473
# 1     2020-01-29T19:04:50Z               100          196652
# ...

# %%
# Independent T-Tests
# Independent t-tests will compare the means of 2 independent populations.

# Assumptions
# Data is normally distributed
# Data is independent
# Data is homogenous (The standard deviations are roughly equal)
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_ind.html

#group by genre here and run independent t-test on different audio features
#do value count of genres and run analysis on ones with most tracks

grouped_play2_df = play2_df.groupby(['Album'])['Energy'].mean()
grouped_play2_df = pd.DataFrame(grouped_play2_df)
grouped_play2_df
# Out:
#                                    Energy
# Album
# #1s ... and then some            0.745333
# (Don't Let The Dragon) Draag On  0.695000
# (It Happens) Sometimes           0.869000
# (some of) Unlovely               0.216850
# +                                0.666000
# ...                                   ...
# yellow is the color of her eyes  0.505000
# ¿Dónde Jugarán Los Niños?        0.903000
# ¿Qué Ha Pasao'?                  0.752000
# Épico                            0.726000
# Éxitos De Yoskar Sarante         0.691000
#
# [3528 rows x 1 columns]

# %%
def energydata(loc1=0, loc2=0):
    rock_energy = #location of data in dataframe
    rap_energy = #location of data in dataframe

    # Scatter Plot of Data
    plt.subplot(2, 1, 1)
    plt.scatter(range(len(rock_energy)), rock_energy, label="Rock - Energy")
    plt.scatter(range(len(rap_energy)), rap_energy, label="Rap - Energy")
    plt.legend()

    # Histogram Plot of Data
    plt.subplot(2, 1, 2)
    plt.hist(rock_energy, 10, density=True, alpha=0.7, label="Rock - Energy")
    plt.hist(rap_energy, 10, density=True, alpha=0.7, label="Rap - Energy")
    plt.axvline(rock_energy.mean(), color='k', linestyle='dashed', linewidth=1)
    plt.axvline(rap_energy.mean(), color='k', linestyle='dashed', linewidth=1)
    plt.legend()  
    
    return rock_energy, rap_energy

# %%
#plot data
rock_energy, rap_energy = energydata()

# %%
#run ttest
stats.ttest_ind(population1, population2, equal_var=False)
