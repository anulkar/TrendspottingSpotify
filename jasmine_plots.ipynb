# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
play_df = pd.read_csv("datasets/spotify_playlists_output.csv")
play_df
# Out:
#       Unnamed: 0                  Track Name        Track Added At  \
# 0              0             Blinding Lights  2020-01-28T11:01:50Z
# 1              1           You should be sad  2020-01-28T11:01:50Z
# 2              2                     The Box  2020-01-28T11:01:50Z
# 3              3                     bad guy  2020-01-28T11:01:50Z
# 4              4                     Falling  2020-01-28T11:01:50Z
# ...          ...                         ...                   ...
# 1536        1536  B*tch From Da Souf (Remix)  2020-01-17T05:01:00Z
# 1537        1537                  God's Hand  2020-01-17T05:01:00Z
# 1538        1538                       Betta  2020-01-17T05:01:00Z
# 1539        1539                    Still Me  2020-01-17T05:01:00Z
# 1540        1540             Suburban, Pt. 2  2020-01-17T05:01:00Z
#
#       Track Popularity  Track Duration  Available Markets  \
# 0                   98          201573                 79
# 1                   89          205473                 79
# 2                  100          196652                 78
# 3                   95          194087                 79
# 4                   98          159381                 79
# ...                ...             ...                ...
# 1536                69          224119                 79
# 1537                34          154966                  0
# 1538                57          213529                 78
# 1539                60          144000                 78
# 1540                65          190746                 78
#
#                                          Album Album Type  \
# 0                              Blinding Lights     single
# 1                            You should be sad     single
# 2        Please Excuse Me For Being Antisocial      album
# 3     WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?      album
# 4                                      Falling     single
# ...                                        ...        ...
# 1536                B*tch From Da Souf (Remix)     single
# 1537                                God's Hand     single
# 1538                                     Betta     single
# 1539                       The Hood Dictionary      album
# 1540                           Suburban, Pt. 2     single
#
#                        Artist Release Date
# 0                 |The Weeknd   2019-11-29
# 1                     |Halsey   2020-01-10
# 2                |Roddy Ricch   2019-12-06
# 3              |Billie Eilish   2019-03-29
# 4              |Trevor Daniel   2018-10-05
# ...                       ...          ...
# 1536  |Mulatto|Saweetie|Trina   2019-12-04
# 1537               |Lil Poppa   2019-12-03
# 1538                  |2KBABY   2019-12-06
# 1539                   |NoCap   2019-11-19
# 1540                    |22Gz   2019-11-29
#
# [1541 rows x 10 columns]

# %%
play_df.plot(kind="scatter", x='Available Markets', y='Track Popularity', grid=True,
              title='Popularity vs. Available Markets', edgecolors='black', color='green')

# %%
play_df.plot(kind="scatter", x='Track Duration', y='Track Popularity', grid=True,
              title='Popularity vs. Duration', edgecolors='black', color='green')

# %%
play2_df = pd.read_csv("datasets/playlist_top_5_output.csv")
play2_df
# Out:
#       Unnamed: 0             Playlist ID           Track Name  \
# 0              0  37i9dQZF1DXasneILDRM7B    You should be sad
# 1              1  37i9dQZF1DXasneILDRM7B              The Box
# 2              2  37i9dQZF1DXasneILDRM7B              bad guy
# 3              3  37i9dQZF1DXasneILDRM7B      Blinding Lights
# 4              4  37i9dQZF1DXasneILDRM7B              Falling
# ...          ...                     ...                  ...
# 4395        4395  37i9dQZF1DXasneILDRM7B  Last Young Renegade
# 4396        4396  37i9dQZF1DXasneILDRM7B       I'm Just A Kid
# 4397        4397  37i9dQZF1DXasneILDRM7B       Gives You Hell
# 4398        4398  37i9dQZF1DXasneILDRM7B        Dead and Gone
# 4399        4399  37i9dQZF1DXasneILDRM7B           Wide Awake
#
#                     Track ID        Track Added At  Track Popularity  \
# 0     1gBDGPFz9v93dxE3fUU9eO  2020-01-29T19:04:50Z                89
# 1     52u4anZbHd6UInnmHRFzba  2020-01-29T19:04:50Z               100
# 2     0S0KGZnfBGSIssfF54WSJh  2020-01-29T19:04:50Z                95
# 3     2ZfHkwHuoAZrlz7RMj0PDz  2020-01-29T19:04:50Z                98
# 4     1Czfd5tEby3DbdYNdqzrCa  2020-01-29T19:04:50Z                98
# ...                      ...                   ...               ...
# 4395  78SBp5vPimhQrP4rJdZXUB  2020-01-20T10:54:16Z                40
# 4396  3rEl0zv6lbVZiB79uHAQ5y  2020-01-20T10:54:16Z                 8
# 4397  3E961jCaL42uhujX1hjMLM  2020-01-20T10:54:16Z                 8
# 4398  1Qb73C8hC76e3R8udyit5I  2020-01-20T10:54:16Z                53
# 4399  6W3xKG9ZmCnmWVU0vqqYL7  2020-01-20T10:54:16Z                44
#
#       Track Duration  Available Markets  \
# 0             205473                 79
# 1             196652                 78
# 2             194087                 79
# 3             201573                 79
# 4             159381                 79
# ...              ...                ...
# 4395          214093                 77
# 4396          198333                  0
# 4397          213106                  0
# 4398          191756                 77
# 4399          193905                 79
#
#                                          Album Album Type  \
# 0                            You should be sad     single
# 1        Please Excuse Me For Being Antisocial      album
# 2     WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?      album
# 3                              Blinding Lights     single
# 4                                      Falling     single
# ...                                        ...        ...
# 4395                       Last Young Renegade     single
# 4396          No Pads, No Helmets...Just Balls      album
# 4397                 When The World Comes Down      album
# 4398                              Living Proof      album
# 4399                    Are You Feeling Alive?     single
#
#                          Artist Release Date
# 0                       |Halsey   2020-01-10
# 1                  |Roddy Ricch   2019-12-06
# 2                |Billie Eilish   2019-03-29
# 3                   |The Weeknd   2019-11-29
# 4                |Trevor Daniel   2018-10-05
# ...                         ...          ...
# 4395              |All Time Low   2017-03-23
# 4396               |Simple Plan   2002-03-19
# 4397  |The All-American Rejects   2008-01-01
# 4398              |State Champs   2018-06-15
# 4399                  |Hot Milk   2019-05-03
#
# [4400 rows x 12 columns]

# %%
play2_df.plot(kind="scatter", x='Available Markets', y='Track Popularity', grid=True,
              title='Popularity vs. Available Markets', edgecolors='black', color='green')

# %%
play2_df.plot(kind="scatter", x='Track Duration', y='Track Popularity', grid=True,
              title='Popularity vs. Duration', edgecolors='black', color='green')
