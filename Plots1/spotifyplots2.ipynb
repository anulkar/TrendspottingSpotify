# %%
# Dependencies and Setup

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import date
import scipy.stats as st

# File to Load (Remember to Change These)
file_to_load = "../datasets/playlist_top_5_output.csv"

# Read Purchasing File and store into Pandas data frame
playlist_data = pd.read_csv(file_to_load)

playlist_data
# Out:
#       Unnamed: 0             Playlist ID                Track ID  \
# 0              0  37i9dQZF1DXcBWIGoYBM5M  2usxQITOSDqvkYiI0oIwao
# 1              1  37i9dQZF1DXcBWIGoYBM5M  0nbXyq5TXYPCO7pr3N8S4I
# 2              2  37i9dQZF1DXcBWIGoYBM5M  2Fxmhks0bxGSBdJ92vM42m
# 3              3  37i9dQZF1DXcBWIGoYBM5M  0sf12qNH5qcw8qpgymFOqD
# 4              4  37i9dQZF1DXcBWIGoYBM5M  4TnjEaWOeW0eKTKIEvJyCa
# ...          ...                     ...                     ...
# 4428        4428  37i9dQZF1DXasneILDRM7B  2zb0TZbEprJhFjrbW74cWt
# 4429        4429  37i9dQZF1DXasneILDRM7B  1wYJnu1hMrYMNrkXKTVrYd
# 4430        4430  37i9dQZF1DXasneILDRM7B  6tQofm7cDQwiG32FVF1HAx
# 4431        4431  37i9dQZF1DXasneILDRM7B  64kDGEpOWlkv2l6x4TVNOs
# 4432        4432  37i9dQZF1DXasneILDRM7B  6VWhABO2EFziQCSKzGWdWF
#
#       Track Position         Track Name        Track Added At  \
# 0                  1  You should be sad  2020-01-29T19:04:50Z
# ...

# %%
# Popularity Vs Valence
playlist_data["Track Popularity"].astype(int)

playlist_data.plot(kind='scatter', x='Track Popularity', y='Tempo', c='Red')
plt.title('Popularity vs Tempo')
plt.xlabel('')
plt.ylabel('')
plt.grid()

# %%
# Popularity Vs Valence
playlist_data["Track Popularity"].astype(int)

playlist_data.plot(kind='scatter', x='Track Popularity', y='Valence', c='Red')
plt.title('Popularity vs Valence')
plt.xlabel('')
plt.ylabel('')
plt.grid()

# %%
# Popularity Vs Instrumentalness
playlist_data["Track Popularity"].astype(int)

playlist_data.plot(kind='scatter', x='Track Popularity', y='Instrumentalness', c='Red')
plt.title('Popularity vs Instrumentalness')
plt.xlabel('')
plt.ylabel('')
plt.grid()

# %%
# Popularity Vs Liveness
playlist_data["Track Popularity"].astype(int)

playlist_data.plot(kind='scatter', x='Track Popularity', y='Liveness', c='Red')
plt.title('Popularity vs Liveness')
plt.xlabel('')
plt.ylabel('')
plt.grid()

# %%
# Popularity Vs Track Postion
playlist_data["Track Popularity"].astype(int)

playlist_data.plot(kind='scatter', x='Track Popularity', y='Track Position', c='Red')
plt.title('Popularity vs Track Position')
plt.xlabel('')
plt.ylabel('')
plt.grid()

# %%
# Popularity Vs Dancibility
playlist_data["Track Popularity"].astype(int)

playlist_data.plot(kind='scatter', x='Track Popularity', y='Danceability', c='Red')
plt.title('Popularity vs Danceability')
plt.xlabel('')
plt.ylabel('')
plt.grid()

# %%
# Popularity Vs Acousticness

playlist_data.plot(kind='scatter', x='Track Popularity', y='Acousticness', c='Red')
plt.title('Popularity vs Acousticness')
plt.xlabel('')
plt.ylabel('')
plt.grid()

# %%
# Popularity Vs Tempo

playlist_data.plot(kind='scatter', x='Track Popularity', y='Tempo', c='Red')
plt.title('Popularity vs Tempo')
plt.xlabel('')
plt.ylabel('')
plt.grid()

# %%
#Album type

type_count = playlist_data["Album Type"].value_counts()

type_count.plot(kind= "bar", title="data points per album type")

# %%
# group by album
type_group = playlist_data.groupby(["Album Type"])

avg_pop = type_group["Track Popularity"].mean()

avg_pop = avg_pop.sort_values(ascending = False)

type_avg = pd.DataFrame({"Avg Score": avg_pop})

print(type_avg)


#Create AVG Pop score Graph

type_avg.plot(kind="bar")
# Out:
#              Avg Score
# Album Type
# album        55.703158
# single       54.213469
# compilation  50.493976

# %%
# Popularity Vs time Sig

playlist_data.plot(kind='scatter', x='Track Popularity', y='Loudness', c='Red')
plt.title('Popularity vs Loudness')
plt.xlabel('')
plt.ylabel('')
plt.grid()

# %%
# Popularity Vs Speechiness

playlist_data.plot(kind='scatter', x='Track Popularity', y='Speechiness', c='Red')
plt.title('Popularity vs Speechiness')
plt.xlabel('')
plt.ylabel('')
plt.grid()

# %%
# Popularity Vs Energy

playlist_data.plot(kind='scatter', x='Track Popularity', y='Energy', c='Red')
plt.title('Popularity vs Energy')
plt.xlabel('')
plt.ylabel('')
plt.grid()
